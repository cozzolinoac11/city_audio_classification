# %% [markdown]
# # Audio SVM
#
# ### Importing all libraries

# %%
from google.colab import drive
from sklearn import metrics
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.multiclass import OneVsRestClassifier
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
import numpy as np 
import matplotlib.pyplot as plt
from sklearn.model_selection import cross_val_score
import pickle

# %% [markdown]
# ### Connecting to Google Drive

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Loading datasets (Numpy arrays)
# Datasets are saved in numpy arrays for load its quickly

# %%
X_train = np.load('/content/drive/MyDrive/ml_dl/audio-2/training_set/X_train.npy')
y_train = np.load('/content/drive/MyDrive/ml_dl/audio-2/training_set/y_train.npy')

X_validation = np.load('/content/drive/MyDrive/ml_dl/audio-2/validation_set/X_validation.npy')
y_validation = np.load('/content/drive/MyDrive/ml_dl/audio-2/validation_set/y_validation.npy')

X_test = np.load('/content/drive/MyDrive/ml_dl/audio-2/test_set/X_test.npy')
y_test = np.load('/content/drive/MyDrive/ml_dl/audio-2/test_set/y_test.npy')

X = np.load('/content/drive/MyDrive/ml_dl/audio-2/dataset/X.npy')
y = np.load('/content/drive/MyDrive/ml_dl/audio-2/dataset/y.npy')

# %% [markdown]
# ### SVC kernel selection

# %%
kernel = ['poly', 'rbf', 'sigmoid']
acc = []

for i in kernel:
  svm = make_pipeline(StandardScaler(), SVC(kernel = i))
  svm.fit(X_train, y_train)
  y_pred = svm.predict(X_validation)
  a = metrics.accuracy_score(y_validation, y_pred)
  acc.append(a)
  print(i + ': ' + str(a))
# Out:
# poly: 0.6319444444444444
# rbf: 0.9097222222222222
# sigmoid: 0.7708333333333334

# %%
plt.figure(figsize=(15, 6))
plt.plot(kernel, acc)
plt.title("Kernel performance")
plt.xlabel("Kernel")
plt.ylabel("Accuracy")
plt.grid(True)
plt.show()

# %% [markdown]
# ### Training the best model

# %%
svm = make_pipeline(StandardScaler(), SVC())
svm.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()), ('svc', SVC())])

# %% [markdown]
# ### Testing on test set

# %%
y_pred = svm.predict(X_test)
print("Accuracy:", metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.8969072164948454

# %% [markdown]
# ### 10-fold Cross Validation

# %%
scores = cross_val_score(svm, X = X, y = y, cv=10, n_jobs=-1)
accuracy_CV10 = np.mean(scores)
print('Cross Validation accuracy: ' + str(accuracy_CV10))
# Out:
# Cross Validation accuracy: 0.941967213114754

# %% [markdown]
# ### Saving the best model

# %%
model_path = "/content/drive/MyDrive/ml_dl/audio-2/models/audio_SVM.pkl"

# save
with open(model_path,'wb') as f:
    pickle.dump(svm,f)

# load
with open(model_path, 'rb') as f:
    svm = pickle.load(f)
